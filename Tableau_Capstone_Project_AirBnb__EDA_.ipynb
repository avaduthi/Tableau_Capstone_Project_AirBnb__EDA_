# %% [markdown]
# # **Project Name**    - Transforming EDA Project to Dashboard

# %% [markdown]
# # **GitHub repository link -*https://github.com/avaduthi/EDA_automobiles1/blob/main/Tableau_Capstone_Project_AirBnb__EDA_.ipynb*

# %% [markdown]
# ##### **Project Type**    - Dashboard
# ##### **Contribution**    - Individual

# %% [markdown]
# GitHub repository link :

# %% [markdown]
# # **Tableau Dashboard Link**

# %% [markdown]
# Tableau Dashboard Link:https://public.tableau.com/app/profile/ashok.kumar2243/viz/Airbnb_dashboard_Book1_17069300867250/Airbnbdashboard

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In the context of Airbnb operations, how can the utilisation of Tableau facilitate a comprehensive comparative examination between Chicago and New Orleans, two diverse urban environments?
#
# This inquiry seeks to leverage Tableau's visual analytics capabilities to uncover and illustrate the shared attributes, disparities, and distinctive patterns inherent to Airbnb's presence in these cities, thus elevating the depth and insightfulness of the study.

# %% [markdown]
# # ***Let's Begin !***

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Mount the drive to google colab by running below code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
path_chicago='path'
path_New_Orleans='path'

# Read the dateset by using .read_csv() method
data_Chicago=pd.read_csv(path_chicago)
data_New_Orleans=pd.read_csv(path_New_Orleans)

# Add a "City" column with corresponding city names
data_Chicago['City'] = 'Chicago'
data_New_Orleans['City'] = 'New Orleans'

# Creating the Pandas dataframe by using .DataFrame() method then assing it to variable df
df_chicago=pd.DataFrame(data_Chicago)
df_new_orleans=pd.DataFrame(data_New_Orleans)

# %%
# Use pd.concat() to stack df2 below df1
df_airbnb_listing = pd.concat([df_chicago, df_new_orleans], ignore_index=True)

# %%
# Dataset First Look for chicago dataset
df_airbnb_listing.head()
# Out:
#          id                          listing_url     scrape_id last_scraped  \
# 0    2384.0    https://www.airbnb.com/rooms/2384  2.023060e+13   18-06-2023
# 1    7126.0    https://www.airbnb.com/rooms/7126  2.023060e+13   18-06-2023
# 2  755701.0  https://www.airbnb.com/rooms/755701  2.023060e+13   18-06-2023
# 3   10945.0   https://www.airbnb.com/rooms/10945  2.023060e+13   18-06-2023
# 4  790934.0  https://www.airbnb.com/rooms/790934  2.023060e+13   18-06-2023
#
#             source                                               name  \
# 0      city scrape  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      city scrape  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      city scrape  Rental unit in Chicago · ★4.73 · 3 bedrooms · ...
# 3      city scrape  Rental unit in Chicago · ★4.64 · 2 bedrooms · ...
# 4  previous scrape  Rental unit in Chicago · ★4.66 · 1 bedroom · 1...
#
#                                          description  \
# 0  You are invited to be the sole Airbnb guest in...
# 1  A very small studio in a wonderful neighborhoo...
# 2  This is a wonderful, bright, very clean and mo...
# 3  Beautiful first floor apartment in Historic Ol...
# 4  This is for the pullout sofa bed in my living ...
#
#                                neighborhood_overview  \
# 0  The apartment is less than one block from beau...
# 1  Ukrainian Village was just named "Hottest Neig...
# 2  Logan Square is an official community area, hi...
# 3                                                NaN
# 4  We are in the far north neighborhood of Chicag...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/acf6b3c0-47f2...     2613  ...
# 1  https://a0.muscache.com/pictures/51073/16c81c7...    17928  ...
# 2  https://a0.muscache.com/pictures/40393621/bb8c...  3920450  ...
# 3  https://a0.muscache.com/pictures/58d1a420-a24b...    33004  ...
# 4  https://a0.muscache.com/pictures/83010476/8126...  2907254  ...
#
#   review_scores_location review_scores_value                    license  \
# 0                   4.96                4.94                        NaN
# 1                   4.88                4.75               R21000075737
# 2                   4.57                4.71  City registration pending
# 3                   4.98                4.62                    2209984
# 4                   4.44                4.68               R21000075752
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                f                              1
# 2                f                              4
# 3                t                              7
# 4                f                             16
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           4
# 3                                           7
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month     City
# 0                                           0              2.14  Chicago
# 1                                           0              2.90  Chicago
# 2                                           0              0.22  Chicago
# 3                                           0              0.59  Chicago
# 4                                          12              1.08  Chicago
#
# [5 rows x 76 columns]

# %%
# Dataset Rows & Columns count
df_airbnb_listing.shape
# Out:
# (14807, 76)

# %%
# Dataset Info
df_airbnb_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14807 entries, 0 to 14806
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            14807 non-null  float64
#  1   listing_url                                   14807 non-null  object
#  2   scrape_id                                     14807 non-null  float64
#  3   last_scraped                                  14807 non-null  object
#  4   source                                        14807 non-null  object
#  5   name                                          14807 non-null  object
#  6   description                                   14780 non-null  object
#  7   neighborhood_overview                         10581 non-null  object
#  8   picture_url                                   14807 non-null  object
#  9   host_id                                       14807 non-null  int64
#  10  host_url                                      14807 non-null  object
#  11  host_name                                     14807 non-null  object
#  12  host_since                                    14807 non-null  object
#  13  host_location                                 11722 non-null  object
#  14  host_about                                    9487 non-null   object
#  15  host_response_time                            12522 non-null  object
#  16  host_response_rate                            12522 non-null  object
#  17  host_acceptance_rate                          12918 non-null  object
#  18  host_is_superhost                             12932 non-null  object
#  19  host_thumbnail_url                            14807 non-null  object
#  20  host_picture_url                              14807 non-null  object
#  21  host_neighbourhood                            13992 non-null  object
#  22  host_listings_count                           14807 non-null  int64
#  23  host_total_listings_count                     14807 non-null  int64
#  24  host_verifications                            14807 non-null  object
#  25  host_has_profile_pic                          14807 non-null  object
#  26  host_identity_verified                        14807 non-null  object
#  27  neighbourhood                                 10582 non-null  object
#  28  neighbourhood_cleansed                        14807 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      14807 non-null  float64
#  31  longitude                                     14807 non-null  float64
#  32  property_type                                 14807 non-null  object
#  33  room_type                                     14807 non-null  object
#  34  accommodates                                  14807 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                14787 non-null  object
#  37  bedrooms                                      12036 non-null  float64
#  38  beds                                          14717 non-null  float64
#  39  amenities                                     14807 non-null  object
#  40  price                                         14807 non-null  object
#  41  minimum_nights                                14807 non-null  int64
#  42  maximum_nights                                14807 non-null  int64
#  43  minimum_minimum_nights                        14807 non-null  int64
#  44  maximum_minimum_nights                        14807 non-null  int64
#  45  minimum_maximum_nights                        14807 non-null  int64
#  46  maximum_maximum_nights                        14807 non-null  int64
#  47  minimum_nights_avg_ntm                        14807 non-null  float64
#  48  maximum_nights_avg_ntm                        14807 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              14807 non-null  object
#  51  availability_30                               14807 non-null  int64
#  52  availability_60                               14807 non-null  int64
#  53  availability_90                               14807 non-null  int64
#  54  availability_365                              14807 non-null  int64
#  55  calendar_last_scraped                         14807 non-null  object
#  56  number_of_reviews                             14807 non-null  int64
#  57  number_of_reviews_ltm                         14807 non-null  int64
#  58  number_of_reviews_l30d                        14807 non-null  int64
#  59  first_review                                  12257 non-null  object
#  60  last_review                                   12257 non-null  object
#  61  review_scores_rating                          12257 non-null  float64
#  62  review_scores_accuracy                        12232 non-null  float64
#  63  review_scores_cleanliness                     12234 non-null  float64
#  64  review_scores_checkin                         12233 non-null  float64
#  65  review_scores_communication                   12232 non-null  float64
#  66  review_scores_location                        12233 non-null  float64
#  67  review_scores_value                           12232 non-null  float64
#  68  license                                       11367 non-null  object
#  69  instant_bookable                              14807 non-null  object
#  70  calculated_host_listings_count                14807 non-null  int64
#  71  calculated_host_listings_count_entire_homes   14807 non-null  int64
#  72  calculated_host_listings_count_private_rooms  14807 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   14807 non-null  int64
#  74  reviews_per_month                             12257 non-null  float64
#  75  City                                          14807 non-null  object
# dtypes: float64(19), int64(21), object(36)
# memory usage: 8.6+ MB

# %%
# Dataset Columns
df_airbnb_listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'City'],
#       dtype='object')

# %% [markdown]
# **Variables Description**
#
# id: Unique ID assigned to each listing.
#
#
# ---
#
#
# name: Name of the listing.
#
#
# ---
#
#
# host_id: Unique ID assigned to each host.
#
#
# ---
#
#
# host_name: Name of the host.
#
#
# ---
#
#
#
# neighbourhood_group: Group or region where the
# listing is located.
#
#
# ---
#
#
# neighborhood: Neighborhood where the listing is situated.
#
# ---
#
#
#
# latitude: Latitude range of the listing's location.
#
#
# ---
#
#
# longitude: Longitude range of the listing's location.
#
#
# ---
#
#
# room_type: Type of listing, categorized as "Entire home," "Private room," or "Shared room."
#
#
# ---
#
#
# price: Price of the listing per night.
#
#
# ---
#
#
# minimum_nights: Minimum number of nights required for booking the listing.
#
#
# ---
#
#
# number_of_reviews: Total number of reviews received for the listing.
#
#
# ---
#
#
# last_review: Content of the last review received for the listing.
#
#
# ---
#
#
# reviews_per_month: Average count of reviews per month for the listing.
#
#
# ---
#
#
# calculated_host_listing_count: Number of listings managed by the host.
#
#
# ---
#
#
# availability_365: Availability of the listing throughout the year, measured in the number of days.
#
#
# ---
#
#
# Note: Listing is nothing but the property of host

# %%
# Using isin() method for keeping those columns which are needed and droping all columns
df_airbnb_listing = df_airbnb_listing.loc[:, df_airbnb_listing.columns.isin(['id','name','host_id','host_name','neighbourhood','neighbourhood_group_cleansed','latitude',
       'longitude','room_type','minimum_nights','price','number_of_reviews','last_review','reviews_per_month','availability_365','City','property_type'])]
df_airbnb_listing.head()
# Out:
#          id                                               name  host_id  \
# 0    2384.0  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...     2613
# 1    7126.0  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...    17928
# 2  755701.0  Rental unit in Chicago · ★4.73 · 3 bedrooms · ...  3920450
# 3   10945.0  Rental unit in Chicago · ★4.64 · 2 bedrooms · ...    33004
# 4  790934.0  Rental unit in Chicago · ★4.66 · 1 bedroom · 1...  2907254
#
#      host_name                     neighbourhood  \
# 0      Rebecca  Chicago, Illinois, United States
# 1        Sarah  Chicago, Illinois, United States
# 2          Vas  Chicago, Illinois, United States
# 3  At Home Inn                               NaN
# 4          Joe  Chicago, Illinois, United States
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                           NaN  41.78790  -87.58780
# 1                           NaN  41.90166  -87.68021
# 2                           NaN  41.93115  -87.71836
# 3                           NaN  41.91196  -87.63981
# 4                           NaN  42.01653  -87.68788
#
#                 property_type        room_type    price  minimum_nights  \
# 0       Private room in condo     Private room  $129.00               3
# 1          Entire rental unit  Entire home/apt   $94.00              32
# 2          Entire rental unit  Entire home/apt  $100.00              32
# 3          Entire rental unit  Entire home/apt  $219.00               4
# 4  Shared room in rental unit      Shared room  $234.00               1
#
#    availability_365  number_of_reviews last_review  reviews_per_month     City
# 0               350                220  10-06-2023               2.14  Chicago
# 1               295                493  28-05-2023               2.90  Chicago
# 2               198                 27  01-12-2022               0.22  Chicago
# 3                94                 66  07-06-2023               0.59  Chicago
# 4                 0                139  03-02-2020               1.08  Chicago

# %%
# Dataset Describe
df_airbnb_listing.describe(include='all')
# Out:
#                   id                                               name  \
# count   1.480700e+04                                              14807
# unique           NaN                                               7116
# top              NaN  Rental unit in Chicago · 1 bedroom · 1 bed · 1...
# freq             NaN                                                513
# mean    2.986544e+17                                                NaN
# std     3.727153e+17                                                NaN
# min     2.384000e+03                                                NaN
# 25%     2.910562e+07                                                NaN
# 50%     4.973069e+07                                                NaN
# 75%     7.059170e+17                                                NaN
# max     9.717560e+17                                                NaN
#
#              host_id   host_name                     neighbourhood  \
# count   1.480700e+04       14807                             10582
# unique           NaN        3239                                27
# top              NaN  Blueground  Chicago, Illinois, United States
# freq             NaN         655                              5711
# mean    1.724163e+08         NaN                               NaN
# std     1.611634e+08         NaN                               NaN
# min     9.710000e+02         NaN                               NaN
# 25%     3.534246e+07         NaN                               NaN
# 50%     1.074344e+08         NaN                               NaN
# 75%     2.904318e+08         NaN                               NaN
# max     5.332983e+08         NaN                               NaN
#
#         neighbourhood_group_cleansed      latitude     longitude  \
# count                            0.0  14807.000000  14807.000000
# unique                           NaN           NaN           NaN
# top                              NaN           NaN           NaN
# freq                             NaN           NaN           NaN
# mean                             NaN     36.426726    -88.767348
# std                              NaN      5.947081      1.202136
# min                              NaN     29.897680    -90.137480
# 25%                              NaN     29.963125    -90.072134
# 50%                              NaN     41.791259    -87.722810
# 75%                              NaN     41.900318    -87.654525
# max                              NaN     42.022200    -87.529541
#
#              property_type        room_type    price  minimum_nights  \
# count                14807            14807    14807    14807.000000
# unique                  62                4      903             NaN
# top     Entire rental unit  Entire home/apt  $100.00             NaN
# freq                  5715            12153      262             NaN
# mean                   NaN              NaN      NaN       15.422368
# std                    NaN              NaN      NaN       34.234316
# min                    NaN              NaN      NaN        1.000000
# 25%                    NaN              NaN      NaN        2.000000
# 50%                    NaN              NaN      NaN        3.000000
# 75%                    NaN              NaN      NaN       30.000000
# max                    NaN              NaN      NaN     1125.000000
#
#         availability_365  number_of_reviews last_review  reviews_per_month  \
# count       14807.000000       14807.000000       12257       12257.000000
# unique               NaN                NaN        1276                NaN
# top                  NaN                NaN  11-06-2023                NaN
# freq                 NaN                NaN         673                NaN
# mean          191.272709          54.789154         NaN           1.841995
# std           126.554705          91.251143         NaN           1.810434
# min             0.000000           0.000000         NaN           0.010000
# 25%            79.000000           2.000000         NaN           0.550000
# 50%           180.000000          20.000000         NaN           1.480000
# 75%           315.000000          70.000000         NaN           2.660000
# max           365.000000        3194.000000         NaN          57.140000
#
#            City
# count     14807
# unique        2
# top     Chicago
# freq       8024
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
# Dataset Duplicate Value Count
df_airbnb_listing.duplicated().sum()
# Out:
# 18

# %%
# printing the shape of dataset
df_airbnb_listing.shape
# Out:
# (14807, 17)

# %%
# Missing Values/Null Values Count
df_airbnb_listing.isnull().sum()
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           0
# neighbourhood                    4225
# neighbourhood_group_cleansed    14807
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# price                               0
# minimum_nights                      0
# availability_365                    0
# number_of_reviews                   0
# last_review                      2550
# reviews_per_month                2550
# City                                0
# dtype: int64

# %%
# Visualizing the missing values
missing_data = df_airbnb_listing.isnull().sum().reset_index()
missing_data.columns = ['Variable', 'Missing Count']

plt.figure(figsize=(10, 6))
sns.barplot(x='Missing Count', y='Variable', data=missing_data, palette='viridis')
plt.title('Missing Values Count')
plt.xlabel('Missing Count')
plt.ylabel('Variable')
plt.show()

# %%
# Droping the neighbourhood_group_cleansed column
df_airbnb_listing.drop(['neighbourhood_group_cleansed'],axis=1, inplace=True)

# %%
# Checking unique values in neighbourhood column
df_airbnb_listing['neighbourhood'].unique()
# Out:
# array(['Chicago, Illinois, United States', nan,
#        'Oak Park, Illinois, United States',
#        'Chicago Heights, Illinois, United States',
#        'Chicago , Illinois, United States',
#        'Bucktown, Chicago, Illinois, United States',
#        'Oak Lawn, Illinois, United States', 'Chicago, United States',
#        'Rogers Park, Il, United States',
#        'Santa Barbara, California, United States',
#        'Chicago, Il, United States',
#        'Harwood Heights, Illinois, United States',
#        '芝加哥, Illinois, United States',
#        'Evergreen Park, Illinois, United States',
#        'Norridge, Illinois, United States',
#        'Riverdale, Illinois, United States',
#        'New Orleans, Louisiana, United States',
#        'ByWater-Marigny, New Orleans, Louisiana, United States',
#        'ByWater-Marigny, New Orleans , Louisiana, United States',
#        'Arabi, Louisiana, United States',
#        'New Orleans, Louisiana, US, Louisiana, United States',
#        'New Orleans, United States', 'New Orleans,, La, United States',
#        'New Orleans , Louisiana, United States',
#        'New Orleans , La, United States',
#        'New orleans, Louisiana, United States',
#        'Gretna, Louisiana, United States',
#        'Terrytown, Louisiana, United States'], dtype=object)

# %%
# Replacing the null values with "unkown" in neighbourhood
df_airbnb_listing['neighbourhood'].fillna('Unknown', inplace=True)

# A custom function which can remove extra spaces
def handle_neighbourhood(value):
  if value=='New Orleans,, La, United States':
    value='New Orleans , La, United States'
  elif value=='芝加哥,Illinois,United States':
    value='Unknown'



  split_value= str(value).split(',')
  result=[]
  for i in split_value :
    i=i.strip()
    result.append(i)
  delimiter = ','
  str_result = delimiter.join(result)
  return str_result.strip()


df_airbnb_listing['neighbourhood_']= df_airbnb_listing['neighbourhood'].apply(handle_neighbourhood)
df_airbnb_listing['neighbourhood_'].apply(str.strip)
df_airbnb_listing['neighbourhood_'].unique()
# Out:
# array(['Chicago,Illinois,United States', 'Unknown',
#        'Oak Park,Illinois,United States',
#        'Chicago Heights,Illinois,United States',
#        'Bucktown,Chicago,Illinois,United States',
#        'Oak Lawn,Illinois,United States', 'Chicago,United States',
#        'Rogers Park,Il,United States',
#        'Santa Barbara,California,United States',
#        'Chicago,Il,United States',
#        'Harwood Heights,Illinois,United States',
#        '芝加哥,Illinois,United States',
#        'Evergreen Park,Illinois,United States',
#        'Norridge,Illinois,United States',
#        'Riverdale,Illinois,United States',
#        'New Orleans,Louisiana,United States',
#        'ByWater-Marigny,New Orleans,Louisiana,United States',
#        'Arabi,Louisiana,United States',
#        'New Orleans,Louisiana,US,Louisiana,United States',
#        'New Orleans,United States', 'New Orleans,La,United States',
#        'New orleans,Louisiana,United States',
#        'Gretna,Louisiana,United States',
#        'Terrytown,Louisiana,United States'], dtype=object)

# %%
# droping the "neighbourhood" column
df_airbnb_listing.drop(['neighbourhood'],axis=1, inplace=True)

# %%
# Calculate an estimated 'last_review' date based on 'number_of_reviews' and 'reviews_per_month'
df_airbnb_listing['last_review'].fillna('unknown', inplace=True)

# %%
# replacing the null values in 'reviews_per_month' with mean value of column
df_airbnb_listing['reviews_per_month'].fillna(df_airbnb_listing['reviews_per_month'].mean(), inplace=True)
# Convert 'reviews_per_month' from float to int
df_airbnb_listing['reviews_per_month'] = df_airbnb_listing['reviews_per_month'].astype(int)

# %%
# printing the unique value of price column
df_airbnb_listing['price'].unique()[0:150]
# Out:
# array(['$129.00', '$94.00', '$100.00', '$219.00', '$234.00', '$85.00',
#        '$92.00', '$120.00', '$110.00', '$86.00', '$130.00', '$200.00',
#        '$136.00', '$50.00', '$95.00', '$295.00', '$89.00', '$133.00',
#        '$91.00', '$251.00', '$79.00', '$312.00', '$179.00', '$246.00',
#        '$45.00', '$140.00', '$108.00', '$118.00', '$60.00', '$132.00',
#        '$170.00', '$138.00', '$48.00', '$149.00', '$204.00', '$32.00',
#        '$103.00', '$256.00', '$692.00', '$212.00', '$146.00', '$102.00',
#        '$175.00', '$449.00', '$250.00', '$27.00', '$75.00', '$184.00',
#        '$119.00', '$279.00', '$51.00', '$101.00', '$193.00', '$67.00',
#        '$558.00', '$141.00', '$64.00', '$70.00', '$134.00', '$220.00',
#        '$196.00', '$115.00', '$153.00', '$225.00', '$82.00', '$159.00',
#        '$96.00', '$608.00', '$822.00', '$150.00', '$1,193.00', '$39.00',
#        '$364.00', '$160.00', '$37.00', '$282.00', '$1,607.00', '$521.00',
#        '$55.00', '$392.00', '$258.00', '$52.00', '$113.00', '$148.00',
#        '$152.00', '$90.00', '$35.00', '$112.00', '$145.00', '$171.00',
#        '$69.00', '$65.00', '$71.00', '$188.00', '$299.00', '$131.00',
#        '$128.00', '$185.00', '$135.00', '$125.00', '$155.00', '$84.00',
#        '$209.00', '$174.00', '$104.00', '$25.00', '$106.00', '$105.00',
#        '$248.00', '$207.00', '$42.00', '$297.00', '$303.00', '$151.00',
#        '$201.00', '$268.00', '$40.00', '$28.00', '$500.00', '$143.00',
#        '$157.00', '$61.00', '$29.00', '$259.00', '$214.00', '$99.00',
#        '$223.00', '$33.00', '$107.00', '$237.00', '$233.00', '$263.00',
#        '$368.00', '$542.00', '$59.00', '$56.00', '$165.00', '$144.00',
#        '$683.00', '$121.00', '$97.00', '$275.00', '$114.00', '$5,000.00',
#        '$187.00', '$63.00', '$245.00', '$183.00', '$127.00', '$298.00'],
#       dtype=object)

# %%
# removing the "$" and "," from price value and convert the datatype to float
df_airbnb_listing['price'] = df_airbnb_listing['price'].str.replace('$', '').str.replace(',', '').astype(float)
df_airbnb_listing = df_airbnb_listing[df_airbnb_listing['price'] > 0]

# %%
# printing the unique value of price column
df_airbnb_listing['price'].unique()[0:150]
# Out:
# array([ 129.,   94.,  100.,  219.,  234.,   85.,   92.,  120.,  110.,
#          86.,  130.,  200.,  136.,   50.,   95.,  295.,   89.,  133.,
#          91.,  251.,   79.,  312.,  179.,  246.,   45.,  140.,  108.,
#         118.,   60.,  132.,  170.,  138.,   48.,  149.,  204.,   32.,
#         103.,  256.,  692.,  212.,  146.,  102.,  175.,  449.,  250.,
#          27.,   75.,  184.,  119.,  279.,   51.,  101.,  193.,   67.,
#         558.,  141.,   64.,   70.,  134.,  220.,  196.,  115.,  153.,
#         225.,   82.,  159.,   96.,  608.,  822.,  150., 1193.,   39.,
#         364.,  160.,   37.,  282., 1607.,  521.,   55.,  392.,  258.,
#          52.,  113.,  148.,  152.,   90.,   35.,  112.,  145.,  171.,
#          69.,   65.,   71.,  188.,  299.,  131.,  128.,  185.,  135.,
#         125.,  155.,   84.,  209.,  174.,  104.,   25.,  106.,  105.,
#         248.,  207.,   42.,  297.,  303.,  151.,  201.,  268.,   40.,
#          28.,  500.,  143.,  157.,   61.,   29.,  259.,  214.,   99.,
#         223.,   33.,  107.,  237.,  233.,  263.,  368.,  542.,   59.,
#          56.,  165.,  144.,  683.,  121.,   97.,  275.,  114., 5000.,
#         187.,   63.,  245.,  183.,  127.,  298.])

# %%
df_airbnb_listing = df_airbnb_listing[df_airbnb_listing['availability_365'] > 0]

# %%
df_airbnb_listing['id'].astype(int)
# Out:
# 0                      2384
# 1                      7126
# 2                    755701
# 3                     10945
# 5                    863120
#                 ...
# 14802    970848000000000000
# 14803    971023000000000000
# 14804    971622000000000000
# 14805    971690000000000000
# 14806    971756000000000000
# Name: id, Length: 13088, dtype: int64

# %%
df_airbnb_listing['host_id'].astype(int)
# Out:
# 0             2613
# 1            17928
# 2          3920450
# 3            33004
# 5          4525503
#            ...
# 14802    442915263
# 14803    428276486
# 14804     68337970
# 14805     14988904
# 14806     33076245
# Name: host_id, Length: 13088, dtype: int64

# %%
# getting the description of dataset
df_airbnb_listing.describe(include='all')
# Out:
#                   id                                               name  \
# count   1.308800e+04                                              13088
# unique           NaN                                               6507
# top              NaN  Rental unit in Chicago · 1 bedroom · 1 bed · 1...
# freq             NaN                                                434
# mean    3.194090e+17                                                NaN
# std     3.772443e+17                                                NaN
# min     2.384000e+03                                                NaN
# 25%     3.161769e+07                                                NaN
# 50%     5.130275e+07                                                NaN
# 75%     7.169998e+17                                                NaN
# max     9.717560e+17                                                NaN
#
#              host_id   host_name      latitude     longitude  \
# count   1.308800e+04       13088  13088.000000  13088.000000
# unique           NaN        2900           NaN           NaN
# top              NaN  Blueground           NaN           NaN
# freq             NaN         577           NaN           NaN
# mean    1.768304e+08         NaN     36.567379    -88.738851
# std     1.633556e+08         NaN      5.933647      1.199311
# min     9.710000e+02         NaN     29.897680    -90.137480
# 25%     3.654527e+07         NaN     29.963450    -90.071500
# 50%     1.107147e+08         NaN     41.800975    -87.717904
# 75%     3.057254e+08         NaN     41.901401    -87.653720
# max     5.332983e+08         NaN     42.022200    -87.529541
#
#              property_type        room_type         price  minimum_nights  \
# count                13088            13088  13088.000000    13088.000000
# unique                  58                4           NaN             NaN
# top     Entire rental unit  Entire home/apt           NaN             NaN
# freq                  5195            10920           NaN             NaN
# mean                   NaN              NaN    211.372097       14.523839
# std                    NaN              NaN    302.644794       35.026644
# min                    NaN              NaN     12.000000        1.000000
# 25%                    NaN              NaN     94.000000        2.000000
# 50%                    NaN              NaN    145.000000        3.000000
# 75%                    NaN              NaN    235.000000       30.000000
# max                    NaN              NaN  10000.000000     1125.000000
#
#         availability_365  number_of_reviews last_review  reviews_per_month  \
# count       13088.000000       13088.000000       13088       13088.000000
# unique               NaN                NaN         964                NaN
# top                  NaN                NaN     unknown                NaN
# freq                 NaN                NaN        2201                NaN
# mean          216.394789          57.511767         NaN           1.439487
# std           112.619412          94.285642         NaN           1.668941
# min             1.000000           0.000000         NaN           0.000000
# 25%           114.000000           2.000000         NaN           0.000000
# 50%           233.000000          22.000000         NaN           1.000000
# 75%           322.000000          74.000000         NaN           2.000000
# max           365.000000        3194.000000         NaN          57.000000
#
#            City                  neighbourhood_
# count     13088                           13088
# unique        2                              18
# top     Chicago  Chicago,Illinois,United States
# freq       7247                            5174
# mean        NaN                             NaN
# std         NaN                             NaN
# min         NaN                             NaN
# 25%         NaN                             NaN
# 50%         NaN                             NaN
# 75%         NaN                             NaN
# max         NaN                             NaN

# %%
# printing the information of dataset
df_airbnb_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13088 entries, 0 to 14806
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 13088 non-null  float64
#  1   name               13088 non-null  object
#  2   host_id            13088 non-null  int64
#  3   host_name          13088 non-null  object
#  4   latitude           13088 non-null  float64
#  5   longitude          13088 non-null  float64
#  6   property_type      13088 non-null  object
#  7   room_type          13088 non-null  object
#  8   price              13088 non-null  float64
#  9   minimum_nights     13088 non-null  int64
#  10  availability_365   13088 non-null  int64
#  11  number_of_reviews  13088 non-null  int64
#  12  last_review        13088 non-null  object
#  13  reviews_per_month  13088 non-null  int64
#  14  City               13088 non-null  object
#  15  neighbourhood_     13088 non-null  object
# dtypes: float64(4), int64(5), object(7)
# memory usage: 1.7+ MB

# %%
# Visualizing the missing values
missing_data = df_airbnb_listing.isnull().sum().reset_index()
missing_data.columns = ['Variable', 'Missing Count']

plt.figure(figsize=(10, 6))
sns.barplot(x='Missing Count', y='Variable', data=missing_data, palette='viridis')
plt.title('Missing Values Count')
plt.xlabel('Missing Count')
plt.ylabel('Variable')
plt.show()

# %%
# To save updated dataset to a CSV file
df_airbnb_listing.to_excel('output_df_airbnb_listing_listings.xlsx', index=False)
